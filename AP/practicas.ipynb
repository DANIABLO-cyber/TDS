# %% [markdown]
# <hr style="border: 1.5px solid orange;">
#
# <h1 style="color: orange;">PRÁCTICA 2</h1>
#
# <hr style="border: 1.5px solid orange;">

# %%
import matplotlib.pyplot as plt
import numpy as np

#! TAREA 1
# Datos extraídos de la tabla
distancia_cm = np.array([20, 30, 40, 50, 60, 70, 80, 90])
voltaje_mV = np.array([435, 265, 195, 140, 120, 93, 72, 65])

# Cálculo de 1/sqrt(V)
inv_sqrt_V = 1 / np.sqrt(voltaje_mV)

# Ajuste lineal para comparación
coef = np.polyfit(distancia_cm, inv_sqrt_V, 1)
fit_line = np.poly1d(coef)

# Gráfica
plt.figure(figsize=(8, 5))
plt.plot(distancia_cm, inv_sqrt_V, 'o', label='Datos experimentales', color='blue')
plt.plot(distancia_cm, fit_line(distancia_cm), '-', label='Ajuste lineal', color='red')

plt.xlabel("Distancia (cm)")
plt.ylabel(r"$\frac{1}{\sqrt{V}}$ (1/$\sqrt{\mathrm{Voltaje}}$)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ángulos en grados
angles_deg = np.array([
    -60, -50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50, 60
])
angles_rad = np.radians(angles_deg)

# Datos normalizados en dB para cada plano
e_plane_db = np.array([
    -44.35, -36.99, -31.13, -27.09, -15.70, -5.35, 0,
    -6.47, -17.97, -28.20, -31.38, -34.34, -43.65
])

h_plane_db = np.array([
    -32.18, -25.38, -23.86, -21.45, -14.70, -6.34, -2.45,
    -6.07, -17.34, -22.45, -23.93, -28.18, -32.93
])

# Normalizar a 0 dB (si no lo están ya)
e_plane_db_norm = e_plane_db - np.max(e_plane_db)
h_plane_db_norm = h_plane_db - np.max(h_plane_db)

# Crear gráfico polar
plt.figure(figsize=(8, 6))
ax = plt.subplot(111, polar=True)

ax.plot(angles_rad, e_plane_db_norm, label='Plano E', color='blue', marker='o')
ax.plot(angles_rad, h_plane_db_norm, label='Plano H', color='red', marker='x')

ax.set_theta_zero_location('N')
ax.set_theta_direction(-1)
ax.set_title('Diagramas de radiación - Planos E y H', va='bottom')
ax.set_rlabel_position(135)
ax.set_rticks([-50, -40, -30, -20, -10, 0])
ax.grid(True)
ax.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ángulos en grados
angles_deg = np.array([
    -60, -50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50, 60
])
angles_rad = np.radians(angles_deg)

# Datos normalizados en dB (extraídos de tu imagen manuscrita)
e_plane_db = np.array([
    -62.36, -56.81, -59.16, -37.77, -29.86, -21.68, -18.60,
    -21.96, -29.21, -39.18, -58.00, -58.16, -63.63
])

h_plane_db = np.array([
    -54.60, -46.05, -42.71, -37.64, -26.76, -19.33, -17.82,
    -20.99, -31.54, -34.43, -40.22, -52.17, -55.30
])

# Normalizar a 0 dB
e_plane_db_norm = e_plane_db - np.max(e_plane_db)
h_plane_db_norm = h_plane_db - np.max(h_plane_db)

# Crear gráfico polar
plt.figure(figsize=(8, 6))
ax = plt.subplot(111, polar=True)

# Graficar plano E (azul) y plano H (rojo)
ax.plot(angles_rad, e_plane_db_norm, label='Plano E', color='blue', marker='o')
ax.plot(angles_rad, h_plane_db_norm, label='Plano H', color='red', marker='x')

# Estética del gráfico
ax.set_theta_zero_location('N')       # 0° en el norte
ax.set_theta_direction(-1)            # sentido horario
ax.set_title('Diagramas de radiación - Planos E y H', va='bottom')
ax.set_rlabel_position(135)           # posición etiquetas radiales
ax.set_rticks([-60, -50, -40, -30, -20, -10, 0])  # etiquetas circulares
ax.grid(True)
ax.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ángulos en grados
angles_deg = np.array([
    -60, -50, -40, -30, -20, -10, 0, 10, 20, 30, 40, 50, 60
])
angles_rad = np.radians(angles_deg)

# Datos con obstáculo (en dB)
e_plane_db_obs = np.array([
    -62.36, -56.81, -59.16, -37.77, -29.86, -21.68, -18.60,
    -21.96, -29.21, -39.18, -58.00, -58.16, -63.63
])

h_plane_db_obs = np.array([
    -54.60, -46.05, -42.71, -37.64, -26.76, -19.33, -17.82,
    -20.99, -31.54, -34.43, -40.22, -52.17, -55.30
])

# Datos sin obstáculo (en dB)
e_plane_db_clear = np.array([
    -44.35, -36.99, -31.13, -27.09, -15.70, -5.35, 0,
    -6.47, -17.97, -28.20, -31.38, -34.34, -43.65
])

h_plane_db_clear = np.array([
    -32.18, -25.38, -23.86, -21.45, -14.70, -6.34, -2.45,
    -6.07, -17.34, -22.45, -23.93, -28.18, -32.93
])

# Normalizar cada conjunto a su propio máximo
e_plane_db_obs_norm = e_plane_db_obs - np.max(e_plane_db_obs)
h_plane_db_obs_norm = h_plane_db_obs - np.max(h_plane_db_obs)
e_plane_db_clear_norm = e_plane_db_clear - np.max(e_plane_db_clear)
h_plane_db_clear_norm = h_plane_db_clear - np.max(h_plane_db_clear)

# Crear figura con dos subplots en columnas (polar)
fig, (ax1, ax2) = plt.subplots(1, 2, subplot_kw={'projection': 'polar'}, figsize=(12, 6))

# Gráfico con obstáculo
ax1.plot(angles_rad, e_plane_db_obs_norm, label='Plano E', color='blue', marker='o')
ax1.plot(angles_rad, h_plane_db_obs_norm, label='Plano H', color='red', marker='x')
ax1.set_theta_zero_location('N')
ax1.set_theta_direction(-1)
ax1.set_rlabel_position(135)
ax1.set_rticks([-60, -50, -40, -30, -20, -10, 0])
ax1.grid(True)
ax1.legend(loc='upper right')

# Gráfico sin obstáculo
ax2.plot(angles_rad, e_plane_db_clear_norm, label='Plano E', color='blue', marker='o')
ax2.plot(angles_rad, h_plane_db_clear_norm, label='Plano H', color='red', marker='x')
ax2.set_theta_zero_location('N')
ax2.set_theta_direction(-1)
ax2.set_rlabel_position(135)
ax2.set_rticks([-60, -50, -40, -30, -20, -10, 0])
ax2.grid(True)
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos experimentales
h_over_R1 = np.array([
    -2.54, -1.69, -1.41, -0.99, -0.85, -0.56, -0.28, 0,
    0.28, 0.56, 0.85, 0.99, 1.13, 1.41, 1.69, 1.97,
    2.25, 2.54, 2.96
])

voltage_db = np.array([
    -45.79, -45.67, -40.29, -34.61, -25.30, -15.41,
    -11.54, -6.41, -3.47, 0, -0.45, -0.53, -0.91,
    -0.42, -0.16, -0.19, -0.23, -0.16, -0.10
])

# Gráfico
plt.figure(figsize=(8, 6))
plt.plot(h_over_R1, voltage_db, 'bo-', label='Medidas experimentales')

plt.title('Atenuación por obstrucción de la zona de Fresnel')
plt.xlabel(r'$h/R_1$')
plt.ylabel('Voltaje normalizado (dB)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Distancias (m)
r = np.array([0.64, 0.67, 0.71, 0.75, 0.79, 0.83, 0.87])

# Datos experimentales: Ed directo (mV) y Ed+r con reflector (mV)
Ed = np.array([67.14, 97.64,  83.53,  74.70,  64.83,  50.20,  54.67])
Edr = np.array([84.16, 122.8, 111.4,   94.74,  79.75,   64.90,   65.81])

# Cociente experimental E_total / E_directo
ratio_exp = Edr / Ed

# Valores teóricos (obtenidos de f(ΔL) = 2|cos(2π·ΔL/λ)| para cada r, en el mismo orden)
ratio_theo = np.array([1.60, 0.67, 1.95, 0.00, 1.80, 1.54, 1.21])

# Dibujamos
plt.figure(figsize=(8,4))
plt.plot(r, ratio_exp, 'o-', lw=2, label='Práctico', color='C0')
plt.plot(r, ratio_theo,'s--', lw=2, label='Teórico', color='C3')

plt.title('Comparación práctico vs. teórico\nde $E^{d+r}/E^d$ frente a distancia $r$')
plt.xlabel('Distancia $r$ (m)')
plt.ylabel('Intensidad relativa $E^{d+r}/E^d$')
plt.grid(True, ls=':')
plt.legend()
plt.tight_layout()
plt.show()
