# %%
import matplotlib.pyplot as plt

# Dato
x = [8, 10, 12.3, 14.6, 17.3, 19.7, 22.4, 25.5, 27.5, 30, 32.9, 34.1, 36.9, 39.1, 41.7]
y = [76, 82, 83, 70, 72, 80, 84, 92, 112, 116, 121, 121.36, 124, 144, 136]

# Normalizar los datos de voltaje
y_max = max(y)
print(f"Voltaje máximo: {y_max}")
y_normalized = [value / y_max for value in y]

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(x, y_normalized, marker="o", linestyle="-", color="blue")
plt.title("Gráfica de los datos")
plt.xlabel("Temperatura [ºC]")
plt.ylabel("Voltaje Normalizado")
plt.ylim(0, 1.1)  # Ajustar el límite del eje Y para datos normalizados
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Voltaje máximo: 144

# %%
import matplotlib.pyplot as plt

x = [
    8.5,
    10.8,
    12.4,
    14.6,
    16.2,
    18.1,
    19.3,
    20.6,
    21.8,
    23.8,
    25.9,
    27.8,
    29.6,
    31.4,
    34.8,
    37.3,
    40.3,
]
y = [
    3.9,
    4.0,
    3.92,
    3.87,
    4.4,
    6.9,
    9.96,
    6.8,
    4.12,
    3.92,
    3.52,
    2.72,
    1.68,
    0.71,
    0.64,
    0.48,
    0.32,
]

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker="o", linestyle="-", color="blue")
plt.title("Gráfica de los datos")
plt.xlabel("Temperatura [ºC]")
plt.ylabel("Voltaje [mV]")
plt.ylim(0, 11)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Primera serie de datos
x1 = [
    8.5, 10.8, 12.4, 14.6, 16.2, 18.1, 19.3, 20.6, 21.8, 23.8,
    25.9, 27.8, 29.6, 31.4, 34.8, 37.3, 40.3,
]
y1_V = [
    3.9, 4.0, 3.92, 3.87, 4.4, 6.9, 9.96, 6.8, 4.12, 3.92,
    3.52, 2.72, 1.68, 0.71, 0.64, 0.48, 0.32,
]
y1 = [v / 100 for v in y1_V]  # Conversión a voltios


# Segunda serie de datos
x2 = [8, 10, 12.3, 14.6, 17.3, 19.7, 22.4, 25.5, 27.5, 30, 32.9, 34.1, 36.9, 39.1, 41.7]
y2_mV = [76, 82, 83, 70, 72, 80, 84, 92, 112, 116, 121, 121.36, 124, 144, 136]
y2 = [v / 1000 for v in y2_mV]  # Conversión a voltios


# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(x1, y1, marker="o", linestyle="-", color="blue", label="Serie 1")
plt.plot(x2, y2, marker="s", linestyle="--", color="red", label="Serie 2")

# Detalles del gráfico
plt.title("Comparación de dos series de datos")
plt.xlabel("Temperatura [ºC]")
plt.ylabel("Voltaje [mV]")
plt.ylim(0, 0,15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 30
#      28 plt.xlabel("Temperatura [ºC]")
#      29 plt.ylabel("Voltaje [mV]")
# ---> 30 plt.ylim(0, 0,15)
#      31 plt.grid(True)
#      32 plt.legend()
#
# File c:\Users\danie\anaconda3\envs\Sistemas_Codif_Almacenamiento\Lib\site-packages\matplotlib\pyplot.py:2160, in ylim(*args, **kwargs)
#    2158 if not args and not kwargs:
#    2159     return ax.get_ylim()
# -> 2160 ret = ax.set_ylim(*args, **kwargs)
#    2161 return ret
#
# TypeError: _AxesBase.set_ylim() takes from 1 to 3 positional arguments but 4 were given

# %% [markdown]
# Cuanto mas se absorbe, mas se excita el materia.

# %% [markdown]
# ___
# # LA COSA SE PONE SERIA
# ___
