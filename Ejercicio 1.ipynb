# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejercicio 1

# %%
import numpy as np

vector = np.zeros(9) # Define un objeto vector

for i in range(9): # Ciclo para llenar el vector
    vector[i] = 101 # Llenado del vector
print("vector = ", vector)
# Out:
# vector =  [101. 101. 101. 101. 101. 101. 101. 101. 101.]

# %% [markdown]
# Ejercicio 2

# %%
# Crear una matriz de 4x6 con distribución normal, varianza unitaria y media 0
matriz_4x6 = np.random.normal(0, 1, (4, 6))

print("matriz_4x6 = \n", matriz_4x6)
# Out:
# matriz_4x6 =
#  [[-1.28261659  0.70460848 -1.8589183   0.15309392  2.86764219  1.14125623]
#  [ 0.52719647 -1.26599889  1.33179165  0.39689832  0.46554751 -0.59302348]
#  [ 0.55618562  0.41120719 -0.41127174  0.26181126 -2.03323277 -0.06244452]
#  [ 0.73848708  0.72673393 -0.78043197  0.56259316 -0.15012103 -0.03473696]]

# %% [markdown]
# Ejercicio 3

# %%
vector_aleatorio = np.random.randint(4, 101, 10)

print("vector_aleatorio = ", vector_aleatorio)
# Out:
# vector_aleatorio =  [72 88 54 35 25 60  7 86 14 68]
